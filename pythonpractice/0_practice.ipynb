# %%
print("hello world")
# Out:
# hello world

# %%
"hello world".replace("world","Python")
# Out:
# 'hello Python'

# %%
a=10
x=float(input("Enter a number: "))
a=x
print(a)
# Out:
# 10.58

# %%
# # initialization 
# # insert
# # delete
# # update
# # sorting
# # reversal

# %%
l1 = [1,3,5]
l2 = [2,4,6]
l3 = l1+l2
print(l3)

l3.sort()
print(l3)
# Out:
# [1, 3, 5, 2, 4, 6]
# [1, 2, 3, 4, 5, 6]

# %%
l1 = [1,3,5]
l2 = [2,4,6]
l3 = l1+l2
print(l3)
l=sorted(l3) 
print(l)
# Out:
# [1, 3, 5, 2, 4, 6]
# [1, 2, 3, 4, 5, 6]

# %%
l3[::-1]
# Out:
# [6, 4, 2, 5, 3, 1]

# %%
print(l3[0:6])  #1,2,3,4,5,6
print(l3[0:])  #1,2,3,4,5

# %%
lst = [1, 2, 3, 4, 5]
print(lst[::0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 lst = [1, 2, 3, 4, 5]
# ----> 2 print(lst[::0])
#
# ValueError: slice step cannot be zero

# %%
lst = [1, 2, 3, 4, 5]
lst[1:3] = [10, 20, 30, 40]
print(lst)
# Out:
# [1, 10, 20, 30, 40, 4, 5]

# %%
lst = [1, 2, 3, 4, 5]
print(lst[20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 lst = [1, 2, 3, 4, 5]
# ----> 2 print(lst[20])
#
# IndexError: list index out of range

# %%
lst = [1, 2, 3, 4, 5]
lst[::2] = [0, 0]
print(lst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 lst = [1, 2, 3, 4, 5]
# ----> 2 lst[::2] = [0, 0]
#       3 print(lst)
#
# ValueError: attempt to assign sequence of size 2 to extended slice of size 3

# %%
l1 = [1,3,5]
l2 = [2,4,6]
l1.append(l2)
print(l1)
# Out:
# [1, 3, 5, [2, 4, 6]]

# %%
l1 = [1,3,5]
l2 = [2,4,6]
#l1.extend(l2)
print(l1+l2)
# Out:
# [1, 3, 5, 2, 4, 6]
